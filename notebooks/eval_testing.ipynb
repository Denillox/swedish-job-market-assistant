# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

from tests.run_evaluation import create_or_get_dataset
from langsmith import Client

client = Client()
dataset = create_or_get_dataset(client)
print(dataset)

# %%
from tests.run_evaluation import target
result = target({"question": "What are the top skills for data engineer roles?"})
print(result)
