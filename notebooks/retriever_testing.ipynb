# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

from assistant.retriever import _load_documents, _split_documents
docs = _load_documents()
chunks = _split_documents(docs)
print(len(chunks))
print(chunks[0].page_content)

# %%
print(chunks[3].page_content)

# %%
from assistant.retriever import _get_vectorstore
vs = _get_vectorstore()
print(vs)

# %%
from assistant.retriever import retrieve_context
print(retrieve_context("what does not_specified workplace type mean?"))
